# %%
import tensorflow as tf
import numpy as np
import xlrd

model_inputs = np.array([])
model_outputs = np.array([])
test_inputs = np.array([])
test_outputs = np.array([])
test_score = np.array([])
model = tf.keras.models.Sequential()

# %%
def loadData(model_first_row, model_final_row, test_first_row, test_final_row):

    global model_inputs, model_outputs, test_inputs, test_outputs, test_score
    # Load Full dataset (masterData)
    ExcelFileName= 'Merval.xls'
    workbook = xlrd.open_workbook(ExcelFileName)
    worksheet = workbook.sheet_by_name("Data") 

    # model_first_row = 2500
    # model_final_row = 3500
    # test_first_row = 3501 
    # test_final_row = 3505

    score_col = 25
    first_col = 26
    final_col = 35

    model_inputs = np.zeros([model_final_row - model_first_row, final_col - first_col])
    model_outputs = np.zeros([model_final_row - model_first_row])

    for row in range(model_first_row - 1, model_final_row - 1):
        cell_value = worksheet.cell_value(row, first_col)
        model_outputs[row - model_first_row + 1] = cell_value

        for col in range(first_col, final_col):
            cell_value = worksheet.cell_value(row, col + 1)
            model_inputs[row - model_first_row + 1, col - first_col] = cell_value


    test_inputs = np.zeros([test_final_row - test_first_row, final_col - first_col])
    test_outputs = np.zeros([test_final_row - test_first_row])
    test_score = np.zeros([test_final_row - test_first_row])

    for row in range(test_first_row - 1, test_final_row - 1):
        cell_value = worksheet.cell_value(row, first_col)
        test_outputs[row - test_first_row + 1] = cell_value
        cell_value = worksheet.cell_value(row, score_col)
        test_score[row - test_first_row + 1] = cell_value

        for col in range(first_col, final_col):
            cell_value = worksheet.cell_value(row, col + 1)
            test_inputs[row - test_first_row + 1, col - first_col] = cell_value

            
def evaluate():
    
    global test_inputs, test_score, model
    wrong = 0.0
    right = 0.0
    none = 0.0
    results = []
    for r in range(len(test_score) ):
        predict = model.predict_classes(test_inputs[r:r+1])[0]
        results.append(predict)
        if ((predict==2 and test_score[r] > 0) or (predict==0 and test_score[r] < 0)):
            right += abs(test_score[r])
        if ((predict==2 and test_score[r] < 0) or (predict==0 and test_score[r] > 0)):
            wrong += abs(test_score[r])
        if (predict==1):
            none += abs(test_score[r])
    return wrong, right, none, results            


def optimize(tries):

    global model_inputs, model_outputs, model
    wrong = right = none = 0.0
    total_wrong = total_right = total_none = 0.0
    res = list()

    for t in range(tries):

        model = tf.keras.models.Sequential()  # a basic feed-forward model
        model.add(tf.keras.layers.Flatten())  # takes our 28x28 and makes it 1x784
        model.add(tf.keras.layers.Dense(3, activation=tf.nn.relu))  # a simple fully-connected layer, 128 units, relu activation
        model.add(tf.keras.layers.Dense(3, activation=tf.nn.relu))  # a simple fully-connected layer, 128 units, relu activation
        model.add(tf.keras.layers.Dense(3, activation=tf.nn.softmax))  # our output layer. 10 units for 10 classes. Softmax for probability distribution

        model.compile(optimizer='adam',  # Good default optimizer to start with
                      loss='sparse_categorical_crossentropy',  # how will we calculate our "error." Neural network aims to minimize loss.
                      metrics=['accuracy'])  # what to track

        model.fit(model_inputs, model_outputs, epochs=100, verbose=0)  # train the model

        results = []
        wrong, right, none, results = evaluate()
        total_wrong += wrong
        total_right += right
        total_none += none
        if (wrong + right == 0):
            result = 0
        else:
            result = 100*(right/(right + wrong))
        res.append(result)
        for t in range(len(results)):
            print("Projected Row:", end = '')
            print(projectedRow, end = ' ')
            print("Result:", end = '')
            print(projectedRow + t, end = ' ')
            print(results[t])

    print("{p:6.2f}".format(p=total_right), end = ' ')
    print("{p:6.2f}".format(p=total_wrong), end = ' ')
    print("{p:6.2f}".format(p=total_none), end = ' ')
    return total_right, total_wrong

# %%
tot_r = tot_w = 0.0
opt_r = opt_w = 0.0
for projectedRow in range(1637, 4700, 1):
    loadData(projectedRow-250, projectedRow-1, projectedRow, projectedRow+10)
    opt_r, opt_w = optimize(1)
    tot_r += opt_r
    tot_w += opt_w
    print( "{p:6.2f}%".format(p=100*(tot_r/(tot_r+tot_w))))
# Out:
# WARNING:tensorflow:From /srv/conda/envs/notebook/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Projected Row:1637 Result:1637 2
# Projected Row:1637 Result:1638 0
# Projected Row:1637 Result:1639 0
# Projected Row:1637 Result:1640 2
# Projected Row:1637 Result:1641 2
# Projected Row:1637 Result:1642 2
# Projected Row:1637 Result:1643 2
# Projected Row:1637 Result:1644 2
# Projected Row:1637 Result:1645 2
# Projected Row:1637 Result:1646 2
#   4.83   5.50   0.00  46.75%
# Projected Row:1638 Result:1638 2
# Projected Row:1638 Result:1639 2
# Projected Row:1638 Result:1640 2
# Projected Row:1638 Result:1641 2
# Projected Row:1638 Result:1642 2
# Projected Row:1638 Result:1643 2
# Projected Row:1638 Result:1644 2
# Projected Row:1638 Result:1645 2
# Projected Row:1638 Result:1646 2
# Projected Row:1638 Result:1647 2
#   4.23   5.84   0.00  44.41%
# Projected Row:1639 Result:1639 2
# Projected Row:1639 Result:1640 2
# Projected Row:1639 Result:1641 2
# Projected Row:1639 Result:1642 2
# Projected Row:1639 Result:1643 2
# Projected Row:1639 Result:1644 2
# Projected Row:1639 Result:1645 2
# Projected Row:1639 Result:1646 2
# Projected Row:1639 Result:1647 2
# Projected Row:1639 Result:1648 2
#   5.06   4.60   0.00  46.97%
# Projected Row:1640 Result:1640 2
# Projected Row:1640 Result:1641 2
# Projected Row:1640 Result:1642 0
# Projected Row:1640 Result:1643 2
# Projected Row:1640 Result:1644 2
# Projected Row:1640 Result:1645 2
# Projected Row:1640 Result:1646 2
# Projected Row:1640 Result:1647 2
# Projected Row:1640 Result:1648 2
# Projected Row:1640 Result:1649 2
#   5.91   4.03   0.00  50.08%
# Projected Row:1641 Result:1641 2
# Projected Row:1641 Result:1642 2
# Projected Row:1641 Result:1643 0
# Projected Row:1641 Result:1644 2
# Projected Row:1641 Result:1645 2
# Projected Row:1641 Result:1646 2
# Projected Row:1641 Result:1647 2
# Projected Row:1641 Result:1648 2
# Projected Row:1641 Result:1649 2
# Projected Row:1641 Result:1650 0
#   6.72   2.91   0.00  53.90%
# Projected Row:1642 Result:1642 0
# Projected Row:1642 Result:1643 2
# Projected Row:1642 Result:1644 2
# Projected Row:1642 Result:1645 2
# Projected Row:1642 Result:1646 2
# Projected Row:1642 Result:1647 2
# Projected Row:1642 Result:1648 2
# Projected Row:1642 Result:1649 0
# Projected Row:1642 Result:1650 2
# Projected Row:1642 Result:1651 2
#   8.85   1.92   0.00  58.94%
# Projected Row:1643 Result:1643 2
# Projected Row:1643 Result:1644 2
# Projected Row:1643 Result:1645 2
# Projected Row:1643 Result:1646 2
# Projected Row:1643 Result:1647 2
# Projected Row:1643 Result:1648 2
# Projected Row:1643 Result:1649 0
# Projected Row:1643 Result:1650 2
# Projected Row:1643 Result:1651 2
# Projected Row:1643 Result:1652 0
#   8.42   1.92   0.00  62.22%
# Projected Row:1644 Result:1644 2
# Projected Row:1644 Result:1645 2
# Projected Row:1644 Result:1646 2
# Projected Row:1644 Result:1647 2
# Projected Row:1644 Result:1648 2
# Projected Row:1644 Result:1649 2
# Projected Row:1644 Result:1650 2
# Projected Row:1644 Result:1651 2
# Projected Row:1644 Result:1652 2
# Projected Row:1644 Result:1653 2
#   6.97   1.93   0.00  64.02%
# Projected Row:1645 Result:1645 2
# Projected Row:1645 Result:1646 2
# Projected Row:1645 Result:1647 2
# Projected Row:1645 Result:1648 2
# Projected Row:1645 Result:1649 2
# Projected Row:1645 Result:1650 2
# Projected Row:1645 Result:1651 2
# Projected Row:1645 Result:1652 2
# Projected Row:1645 Result:1653 2
# Projected Row:1645 Result:1654 2
#   4.98   2.71   0.00  64.09%
# Projected Row:1646 Result:1646 2
# Projected Row:1646 Result:1647 2
# Projected Row:1646 Result:1648 0
# Projected Row:1646 Result:1649 0
# Projected Row:1646 Result:1650 2
# Projected Row:1646 Result:1651 2
# Projected Row:1646 Result:1652 0
# Projected Row:1646 Result:1653 0
# Projected Row:1646 Result:1654 2
# Projected Row:1646 Result:1655 2
#   5.10   2.09   0.00  64.61%
# Projected Row:1647 Result:1647 2
# Projected Row:1647 Result:1648 2
# Projected Row:1647 Result:1649 0
# Projected Row:1647 Result:1650 2
# Projected Row:1647 Result:1651 2
# Projected Row:1647 Result:1652 0
# Projected Row:1647 Result:1653 0
# Projected Row:1647 Result:1654 0
# Projected Row:1647 Result:1655 2
# Projected Row:1647 Result:1656 2
#   7.62   0.22   0.00  67.10%
# Projected Row:1648 Result:1648 2
# Projected Row:1648 Result:1649 2
# Projected Row:1648 Result:1650 2
# Projected Row:1648 Result:1651 2
# Projected Row:1648 Result:1652 2
# Projected Row:1648 Result:1653 2
# Projected Row:1648 Result:1654 2
# Projected Row:1648 Result:1655 2
# Projected Row:1648 Result:1656 2
# Projected Row:1648 Result:1657 2
#   3.79   2.46   0.00  66.73%
# Projected Row:1649 Result:1649 2
# Projected Row:1649 Result:1650 2
# Projected Row:1649 Result:1651 2
# Projected Row:1649 Result:1652 2
# Projected Row:1649 Result:1653 2
# Projected Row:1649 Result:1654 2
# Projected Row:1649 Result:1655 2
# Projected Row:1649 Result:1656 2
# Projected Row:1649 Result:1657 2
# Projected Row:1649 Result:1658 0
#   2.96   2.59   0.00  66.08%
# Projected Row:1650 Result:1650 2
# Projected Row:1650 Result:1651 2
# Projected Row:1650 Result:1652 0
# Projected Row:1650 Result:1653 0
# Projected Row:1650 Result:1654 2
# Projected Row:1650 Result:1655 2
# Projected Row:1650 Result:1656 2
# Projected Row:1650 Result:1657 0
# Projected Row:1650 Result:1658 2
# Projected Row:1650 Result:1659 2
#   3.30   2.47   0.00  65.65%
# Projected Row:1651 Result:1651 2
# Projected Row:1651 Result:1652 2
# Projected Row:1651 Result:1653 2
# Projected Row:1651 Result:1654 2
# Projected Row:1651 Result:1655 2
# Projected Row:1651 Result:1656 2
# Projected Row:1651 Result:1657 2
# Projected Row:1651 Result:1658 0
# Projected Row:1651 Result:1659 0
# Projected Row:1651 Result:1660 2
#   3.92   1.62   0.00  65.88%
# Projected Row:1652 Result:1652 0
# Projected Row:1652 Result:1653 0
# Projected Row:1652 Result:1654 2
# Projected Row:1652 Result:1655 2
# Projected Row:1652 Result:1656 2
# Projected Row:1652 Result:1657 0
# Projected Row:1652 Result:1658 2
# Projected Row:1652 Result:1659 2
# Projected Row:1652 Result:1660 2
# Projected Row:1652 Result:1661 2
#   1.61   3.81   0.00  64.38%
# Projected Row:1653 Result:1653 0
# Projected Row:1653 Result:1654 2
# Projected Row:1653 Result:1655 2
# Projected Row:1653 Result:1656 2
# Projected Row:1653 Result:1657 0
# Projected Row:1653 Result:1658 0
# Projected Row:1653 Result:1659 2
# Projected Row:1653 Result:1660 2
# Projected Row:1653 Result:1661 2
# Projected Row:1653 Result:1662 2
#   1.07   6.52   0.00  61.63%
# Projected Row:1654 Result:1654 2
# Projected Row:1654 Result:1655 2
# Projected Row:1654 Result:1656 2
# Projected Row:1654 Result:1657 2
# Projected Row:1654 Result:1658 2
# Projected Row:1654 Result:1659 2
# Projected Row:1654 Result:1660 2
# Projected Row:1654 Result:1661 2
# Projected Row:1654 Result:1662 0
# Projected Row:1654 Result:1663 2
#   4.91   3.61   0.00  61.39%
# Projected Row:1655 Result:1655 2
# Projected Row:1655 Result:1656 2
# Projected Row:1655 Result:1657 0
# Projected Row:1655 Result:1658 0
# Projected Row:1655 Result:1659 0
# Projected Row:1655 Result:1660 2
# Projected Row:1655 Result:1661 2
# Projected Row:1655 Result:1662 0
# Projected Row:1655 Result:1663 2
# Projected Row:1655 Result:1664 2
#   7.74   1.46   0.00  62.73%
# Projected Row:1656 Result:1656 2
# Projected Row:1656 Result:1657 0
# Projected Row:1656 Result:1658 2
# Projected Row:1656 Result:1659 2
# Projected Row:1656 Result:1660 2
# Projected Row:1656 Result:1661 2
# Projected Row:1656 Result:1662 2
# Projected Row:1656 Result:1663 2
# Projected Row:1656 Result:1664 2
# Projected Row:1656 Result:1665 2
#   3.65   5.48   0.00  61.47%
# Projected Row:1657 Result:1657 0
# Projected Row:1657 Result:1658 0
# Projected Row:1657 Result:1659 0
# Projected Row:1657 Result:1660 2
# Projected Row:1657 Result:1661 2
# Projected Row:1657 Result:1662 0
# Projected Row:1657 Result:1663 2
# Projected Row:1657 Result:1664 2
# Projected Row:1657 Result:1665 2
# Projected Row:1657 Result:1666 2
#   6.69   1.73   0.00  62.34%
# Projected Row:1658 Result:1658 0
# Projected Row:1658 Result:1659 2
# Projected Row:1658 Result:1660 0
# Projected Row:1658 Result:1661 0
# Projected Row:1658 Result:1662 0
# Projected Row:1658 Result:1663 0
# Projected Row:1658 Result:1664 0
# Projected Row:1658 Result:1665 2
# Projected Row:1658 Result:1666 2
# Projected Row:1658 Result:1667 2
#   6.05   4.47   0.00  62.07%
# Projected Row:1659 Result:1659 2
# Projected Row:1659 Result:1660 2
# Projected Row:1659 Result:1661 2
# Projected Row:1659 Result:1662 0
# Projected Row:1659 Result:1663 2
# Projected Row:1659 Result:1664 2
# Projected Row:1659 Result:1665 2
# Projected Row:1659 Result:1666 2
# Projected Row:1659 Result:1667 2
# Projected Row:1659 Result:1668 2
#   7.31   3.77   0.00  62.29%
# Projected Row:1660 Result:1660 2
# Projected Row:1660 Result:1661 2
# Projected Row:1660 Result:1662 2
# Projected Row:1660 Result:1663 2
# Projected Row:1660 Result:1664 2
# Projected Row:1660 Result:1665 2
# Projected Row:1660 Result:1666 2
# Projected Row:1660 Result:1667 2
# Projected Row:1660 Result:1668 2
# Projected Row:1660 Result:1669 2
#   5.34   4.88   0.00  61.79%
# Projected Row:1661 Result:1661 2
# Projected Row:1661 Result:1662 0
# Projected Row:1661 Result:1663 2
# Projected Row:1661 Result:1664 2
# Projected Row:1661 Result:1665 2
# Projected Row:1661 Result:1666 2
# Projected Row:1661 Result:1667 0
# Projected Row:1661 Result:1668 2
# Projected Row:1661 Result:1669 2
# Projected Row:1661 Result:1670 2
#   5.80   4.89   0.00  61.42%
# Projected Row:1662 Result:1662 0
# Projected Row:1662 Result:1663 2
# Projected Row:1662 Result:1664 2
# Projected Row:1662 Result:1665 0
# Projected Row:1662 Result:1666 0
# Projected Row:1662 Result:1667 2
# Projected Row:1662 Result:1668 0
# Projected Row:1662 Result:1669 0
# Projected Row:1662 Result:1670 0
# Projected Row:1662 Result:1671 2
#   9.02   1.22   0.00  62.62%
# Projected Row:1663 Result:1663 2
# Projected Row:1663 Result:1664 2
# Projected Row:1663 Result:1665 2
# Projected Row:1663 Result:1666 2
# Projected Row:1663 Result:1667 0
# Projected Row:1663 Result:1668 0
# Projected Row:1663 Result:1669 0
# Projected Row:1663 Result:1670 2
# Projected Row:1663 Result:1671 2
# Projected Row:1663 Result:1672 2
#   3.29   5.86   0.00  61.59%
# Projected Row:1664 Result:1664 2
# Projected Row:1664 Result:1665 2
# Projected Row:1664 Result:1666 2
# Projected Row:1664 Result:1667 2
# Projected Row:1664 Result:1668 2
# Projected Row:1664 Result:1669 2
# Projected Row:1664 Result:1670 2
# Projected Row:1664 Result:1671 2
# Projected Row:1664 Result:1672 2
# Projected Row:1664 Result:1673 2
#   5.69   3.82   0.00  61.52%
# Projected Row:1665 Result:1665 2
# Projected Row:1665 Result:1666 2
# Projected Row:1665 Result:1667 2
# Projected Row:1665 Result:1668 2
# Projected Row:1665 Result:1669 2
# Projected Row:1665 Result:1670 2
# Projected Row:1665 Result:1671 2
# Projected Row:1665 Result:1672 2
# Projected Row:1665 Result:1673 2
# Projected Row:1665 Result:1674 2
#   4.64   3.82   0.00  61.30%
# Projected Row:1666 Result:1666 0
# Projected Row:1666 Result:1667 0
# Projected Row:1666 Result:1668 0
# Projected Row:1666 Result:1669 0
# Projected Row:1666 Result:1670 2
# Projected Row:1666 Result:1671 0
# Projected Row:1666 Result:1672 0
# Projected Row:1666 Result:1673 0
# Projected Row:1666 Result:1674 2
# Projected Row:1666 Result:1675 2
#   4.17   4.98   0.00  60.75%
# Projected Row:1667 Result:1667 0
# Projected Row:1667 Result:1668 0
# Projected Row:1667 Result:1669 0
# Projected Row:1667 Result:1670 2
# Projected Row:1667 Result:1671 2
# Projected Row:1667 Result:1672 0
# Projected Row:1667 Result:1673 0
# Projected Row:1667 Result:1674 2
# Projected Row:1667 Result:1675 2
# Projected Row:1667 Result:1676 2
#   3.37   6.81   0.00  59.72%
# Projected Row:1668 Result:1668 0
# Projected Row:1668 Result:1669 2
# Projected Row:1668 Result:1670 2
# Projected Row:1668 Result:1671 2
# Projected Row:1668 Result:1672 2
# Projected Row:1668 Result:1673 2
# Projected Row:1668 Result:1674 2
# Projected Row:1668 Result:1675 2
# Projected Row:1668 Result:1676 2
# Projected Row:1668 Result:1677 0
#   3.98   4.92   0.00  59.24%
# Projected Row:1669 Result:1669 0
# Projected Row:1669 Result:1670 0
# Projected Row:1669 Result:1671 2
# Projected Row:1669 Result:1672 2
# Projected Row:1669 Result:1673 2
# Projected Row:1669 Result:1674 2
# Projected Row:1669 Result:1675 2
# Projected Row:1669 Result:1676 2
# Projected Row:1669 Result:1677 0
# Projected Row:1669 Result:1678 0
#   4.85   4.78   0.00  58.95%
# Projected Row:1670 Result:1670 2
# Projected Row:1670 Result:1671 2
# Projected Row:1670 Result:1672 2
# Projected Row:1670 Result:1673 2
# Projected Row:1670 Result:1674 2
# Projected Row:1670 Result:1675 2
# Projected Row:1670 Result:1676 2
# Projected Row:1670 Result:1677 0
# Projected Row:1670 Result:1678 0
# Projected Row:1670 Result:1679 2
#   4.95   4.92   0.00  58.66%
# Projected Row:1671 Result:1671 2
# Projected Row:1671 Result:1672 2
# Projected Row:1671 Result:1673 2
# Projected Row:1671 Result:1674 2
# Projected Row:1671 Result:1675 2
# Projected Row:1671 Result:1676 2
# Projected Row:1671 Result:1677 0
# Projected Row:1671 Result:1678 0
# Projected Row:1671 Result:1679 2
# Projected Row:1671 Result:1680 2
#   5.67   4.17   0.00  58.63%
# Projected Row:1672 Result:1672 2
# Projected Row:1672 Result:1673 2
# Projected Row:1672 Result:1674 2
# Projected Row:1672 Result:1675 2
# Projected Row:1672 Result:1676 2
# Projected Row:1672 Result:1677 0
# Projected Row:1672 Result:1678 0
# Projected Row:1672 Result:1679 2
# Projected Row:1672 Result:1680 2
# Projected Row:1672 Result:1681 2
#   5.67   4.06   0.00  58.62%
# Projected Row:1673 Result:1673 0
# Projected Row:1673 Result:1674 2
# Projected Row:1673 Result:1675 2
# Projected Row:1673 Result:1676 2
# Projected Row:1673 Result:1677 0
# Projected Row:1673 Result:1678 0
# Projected Row:1673 Result:1679 0
# Projected Row:1673 Result:1680 2
# Projected Row:1673 Result:1681 0
# Projected Row:1673 Result:1682 0
#   3.83   4.78   0.00  58.25%
# Projected Row:1674 Result:1674 2
# Projected Row:1674 Result:1675 2
# Projected Row:1674 Result:1676 2
# Projected Row:1674 Result:1677 0
# Projected Row:1674 Result:1678 0
# Projected Row:1674 Result:1679 2
# Projected Row:1674 Result:1680 0
# Projected Row:1674 Result:1681 2
# Projected Row:1674 Result:1682 0
# Projected Row:1674 Result:1683 2
#   3.45   4.05   0.00  57.98%
# Projected Row:1675 Result:1675 2
# Projected Row:1675 Result:1676 2
# Projected Row:1675 Result:1677 2
# Projected Row:1675 Result:1678 2
# Projected Row:1675 Result:1679 2
# Projected Row:1675 Result:1680 2
# Projected Row:1675 Result:1681 0
# Projected Row:1675 Result:1682 0
# Projected Row:1675 Result:1683 2
# Projected Row:1675 Result:1684 0
#   4.58   3.40   0.00  57.96%
# Projected Row:1676 Result:1676 2
# Projected Row:1676 Result:1677 2
# Projected Row:1676 Result:1678 2
# Projected Row:1676 Result:1679 0
# Projected Row:1676 Result:1680 2
# Projected Row:1676 Result:1681 2
# Projected Row:1676 Result:1682 2
# Projected Row:1676 Result:1683 0
# Projected Row:1676 Result:1684 0
# Projected Row:1676 Result:1685 2
#   4.21   3.99   0.00  57.81%
# Projected Row:1677 Result:1677 0
# Projected Row:1677 Result:1678 0
# Projected Row:1677 Result:1679 2
# Projected Row:1677 Result:1680 2
# Projected Row:1677 Result:1681 2
# Projected Row:1677 Result:1682 0
# Projected Row:1677 Result:1683 2
# Projected Row:1677 Result:1684 2
# Projected Row:1677 Result:1685 2
# Projected Row:1677 Result:1686 2
#   5.09   2.99   0.00  57.93%
# Projected Row:1678 Result:1678 0
# Projected Row:1678 Result:1679 2
# Projected Row:1678 Result:1680 2
# Projected Row:1678 Result:1681 0
# Projected Row:1678 Result:1682 0
# Projected Row:1678 Result:1683 2
# Projected Row:1678 Result:1684 0
# Projected Row:1678 Result:1685 2
# Projected Row:1678 Result:1686 2
# Projected Row:1678 Result:1687 0
#   6.48   1.29   0.00  58.46%
# Projected Row:1679 Result:1679 0
# Projected Row:1679 Result:1680 2
# Projected Row:1679 Result:1681 2
# Projected Row:1679 Result:1682 0
# Projected Row:1679 Result:1683 0
# Projected Row:1679 Result:1684 0
# Projected Row:1679 Result:1685 2
# Projected Row:1679 Result:1686 2
# Projected Row:1679 Result:1687 0
# Projected Row:1679 Result:1688 0
#   4.10   3.37   0.00  58.39%
# Projected Row:1680 Result:1680 2
# Projected Row:1680 Result:1681 2
# Projected Row:1680 Result:1682 2
# Projected Row:1680 Result:1683 2
# Projected Row:1680 Result:1684 2
# Projected Row:1680 Result:1685 2
# Projected Row:1680 Result:1686 2
# Projected Row:1680 Result:1687 0
# Projected Row:1680 Result:1688 0
# Projected Row:1680 Result:1689 0
#   3.20   4.05   0.00  58.12%
# Projected Row:1681 Result:1681 2
# Projected Row:1681 Result:1682 2
# Projected Row:1681 Result:1683 2
# Projected Row:1681 Result:1684 2
# Projected Row:1681 Result:1685 2
# Projected Row:1681 Result:1686 2
# Projected Row:1681 Result:1687 2
# Projected Row:1681 Result:1688 2
# Projected Row:1681 Result:1689 2
# Projected Row:1681 Result:1690 2
#   4.74   1.84   0.00  58.36%
# Projected Row:1682 Result:1682 2
# Projected Row:1682 Result:1683 2
# Projected Row:1682 Result:1684 2
# Projected Row:1682 Result:1685 2
# Projected Row:1682 Result:1686 2
# Projected Row:1682 Result:1687 2
# Projected Row:1682 Result:1688 2
# Projected Row:1682 Result:1689 2
# Projected Row:1682 Result:1690 2
# Projected Row:1682 Result:1691 2
#   4.75   1.33   0.00  58.66%
# Projected Row:1683 Result:1683 0
# Projected Row:1683 Result:1684 0
# Projected Row:1683 Result:1685 2
# Projected Row:1683 Result:1686 2
# Projected Row:1683 Result:1687 2
# Projected Row:1683 Result:1688 0
# Projected Row:1683 Result:1689 0
# Projected Row:1683 Result:1690 0
# Projected Row:1683 Result:1691 0
# Projected Row:1683 Result:1692 0
#   3.96   3.04   0.00  58.62%
# Projected Row:1684 Result:1684 2
# Projected Row:1684 Result:1685 2
# Projected Row:1684 Result:1686 2
# Projected Row:1684 Result:1687 0
# Projected Row:1684 Result:1688 0
# Projected Row:1684 Result:1689 0
# Projected Row:1684 Result:1690 0
# Projected Row:1684 Result:1691 0
# Projected Row:1684 Result:1692 2
# Projected Row:1684 Result:1693 0
#   3.46   5.59   0.00  58.18%
# Projected Row:1685 Result:1685 2
# Projected Row:1685 Result:1686 2
# Projected Row:1685 Result:1687 2
# Projected Row:1685 Result:1688 2
# Projected Row:1685 Result:1689 2
# Projected Row:1685 Result:1690 2
# Projected Row:1685 Result:1691 2
# Projected Row:1685 Result:1692 2
# Projected Row:1685 Result:1693 0
# Projected Row:1685 Result:1694 2
#   6.27   2.49   0.00  58.45%
# Projected Row:1686 Result:1686 2
# Projected Row:1686 Result:1687 2
# Projected Row:1686 Result:1688 2
# Projected Row:1686 Result:1689 2
# Projected Row:1686 Result:1690 2
# Projected Row:1686 Result:1691 2
# Projected Row:1686 Result:1692 2
# Projected Row:1686 Result:1693 2
# Projected Row:1686 Result:1694 2
# Projected Row:1686 Result:1695 2
#   8.18   0.06   0.00  59.24%
# Projected Row:1687 Result:1687 0
# Projected Row:1687 Result:1688 0
# Projected Row:1687 Result:1689 0
# Projected Row:1687 Result:1690 0
# Projected Row:1687 Result:1691 2
# Projected Row:1687 Result:1692 0
# Projected Row:1687 Result:1693 0
# Projected Row:1687 Result:1694 2
# Projected Row:1687 Result:1695 2
# Projected Row:1687 Result:1696 0
#   2.04   6.00   0.00  58.61%
# Projected Row:1688 Result:1688 0
# Projected Row:1688 Result:1689 0
# Projected Row:1688 Result:1690 0
# Projected Row:1688 Result:1691 0
# Projected Row:1688 Result:1692 2
# Projected Row:1688 Result:1693 2
# Projected Row:1688 Result:1694 2
# Projected Row:1688 Result:1695 2
# Projected Row:1688 Result:1696 0
# Projected Row:1688 Result:1697 2
#   6.51   1.74   0.00  58.99%
# Projected Row:1689 Result:1689 2
# Projected Row:1689 Result:1690 2
# Projected Row:1689 Result:1691 2
# Projected Row:1689 Result:1692 2
# Projected Row:1689 Result:1693 2
# Projected Row:1689 Result:1694 2
# Projected Row:1689 Result:1695 2
# Projected Row:1689 Result:1696 2
# Projected Row:1689 Result:1697 0
# Projected Row:1689 Result:1698 2
#   6.24   1.71   0.00  59.33%
# Projected Row:1690 Result:1690 2
# Projected Row:1690 Result:1691 2
# Projected Row:1690 Result:1692 2
# Projected Row:1690 Result:1693 0
# Projected Row:1690 Result:1694 2
# Projected Row:1690 Result:1695 2
# Projected Row:1690 Result:1696 0
# Projected Row:1690 Result:1697 2
# Projected Row:1690 Result:1698 2
# Projected Row:1690 Result:1699 2
#   6.27   2.49   0.00  59.56%
# Projected Row:1691 Result:1691 2
# Projected Row:1691 Result:1692 0
# Projected Row:1691 Result:1693 0
# Projected Row:1691 Result:1694 2
# Projected Row:1691 Result:1695 2
# Projected Row:1691 Result:1696 2
# Projected Row:1691 Result:1697 0
# Projected Row:1691 Result:1698 0
# Projected Row:1691 Result:1699 2
# Projected Row:1691 Result:1700 2
#   3.62   6.18   0.00  59.09%
# Projected Row:1692 Result:1692 0
# Projected Row:1692 Result:1693 0
# Projected Row:1692 Result:1694 2
# Projected Row:1692 Result:1695 2
# Projected Row:1692 Result:1696 2
# Projected Row:1692 Result:1697 2
# Projected Row:1692 Result:1698 2
# Projected Row:1692 Result:1699 2
# Projected Row:1692 Result:1700 2
# Projected Row:1692 Result:1701 2
#   5.16   4.74   0.00  58.95%
# Projected Row:1693 Result:1693 0
# Projected Row:1693 Result:1694 2
# Projected Row:1693 Result:1695 2
# Projected Row:1693 Result:1696 2
# Projected Row:1693 Result:1697 2
# Projected Row:1693 Result:1698 2
# Projected Row:1693 Result:1699 2
# Projected Row:1693 Result:1700 2
# Projected Row:1693 Result:1701 0
# Projected Row:1693 Result:1702 2
#   7.10   3.34   0.00  59.14%
# Projected Row:1694 Result:1694 2
# Projected Row:1694 Result:1695 2
# Projected Row:1694 Result:1696 2
# Projected Row:1694 Result:1697 2
# Projected Row:1694 Result:1698 2
# Projected Row:1694 Result:1699 2
# Projected Row:1694 Result:1700 2
# Projected Row:1694 Result:1701 2
# Projected Row:1694 Result:1702 2
# Projected Row:1694 Result:1703 2
#   8.04   1.02   0.00  59.68%
# Projected Row:1695 Result:1695 2
# Projected Row:1695 Result:1696 2
# Projected Row:1695 Result:1697 2
# Projected Row:1695 Result:1698 2
# Projected Row:1695 Result:1699 2
# Projected Row:1695 Result:1700 2
# Projected Row:1695 Result:1701 0
# Projected Row:1695 Result:1702 2
# Projected Row:1695 Result:1703 2
# Projected Row:1695 Result:1704 2
#   7.56   1.31   0.00  60.12%
# Projected Row:1696 Result:1696 2
# Projected Row:1696 Result:1697 0
# Projected Row:1696 Result:1698 0
# Projected Row:1696 Result:1699 2
# Projected Row:1696 Result:1700 2
# Projected Row:1696 Result:1701 2
# Projected Row:1696 Result:1702 2
# Projected Row:1696 Result:1703 2
# Projected Row:1696 Result:1704 2
# Projected Row:1696 Result:1705 0
#   5.42   3.25   0.00  60.16%
# Projected Row:1697 Result:1697 0
# Projected Row:1697 Result:1698 2
# Projected Row:1697 Result:1699 2
# Projected Row:1697 Result:1700 2
# Projected Row:1697 Result:1701 0
# Projected Row:1697 Result:1702 2
# Projected Row:1697 Result:1703 2
# Projected Row:1697 Result:1704 2
# Projected Row:1697 Result:1705 2
# Projected Row:1697 Result:1706 2
#   7.60   1.15   0.00  60.60%
# Projected Row:1698 Result:1698 2
# Projected Row:1698 Result:1699 2
# Projected Row:1698 Result:1700 2
# Projected Row:1698 Result:1701 2
# Projected Row:1698 Result:1702 2
# Projected Row:1698 Result:1703 2
# Projected Row:1698 Result:1704 2
# Projected Row:1698 Result:1705 2
# Projected Row:1698 Result:1706 2
# Projected Row:1698 Result:1707 2
#   7.94   0.52   0.00  61.13%
# Projected Row:1699 Result:1699 2
# Projected Row:1699 Result:1700 2
# Projected Row:1699 Result:1701 0
# Projected Row:1699 Result:1702 2
# Projected Row:1699 Result:1703 2
# Projected Row:1699 Result:1704 2
# Projected Row:1699 Result:1705 2
# Projected Row:1699 Result:1706 2
# Projected Row:1699 Result:1707 2
# Projected Row:1699 Result:1708 2
#   7.25   1.79   0.00  61.44%
# Projected Row:1700 Result:1700 2
# Projected Row:1700 Result:1701 2
# Projected Row:1700 Result:1702 2
# Projected Row:1700 Result:1703 2
# Projected Row:1700 Result:1704 2
# Projected Row:1700 Result:1705 2
# Projected Row:1700 Result:1706 0
# Projected Row:1700 Result:1707 2
# Projected Row:1700 Result:1708 2
# Projected Row:1700 Result:1709 2
#   4.71   3.13   0.00  61.42%
# Projected Row:1701 Result:1701 2
# Projected Row:1701 Result:1702 2
# Projected Row:1701 Result:1703 2
# Projected Row:1701 Result:1704 2
# Projected Row:1701 Result:1705 0
# Projected Row:1701 Result:1706 0
# Projected Row:1701 Result:1707 0
# Projected Row:1701 Result:1708 2
# Projected Row:1701 Result:1709 2
# Projected Row:1701 Result:1710 2
#   3.40   3.86   0.00  61.23%
# Projected Row:1702 Result:1702 2
# Projected Row:1702 Result:1703 2
# Projected Row:1702 Result:1704 2
# Projected Row:1702 Result:1705 2
# Projected Row:1702 Result:1706 2
# Projected Row:1702 Result:1707 2
# Projected Row:1702 Result:1708 2
# Projected Row:1702 Result:1709 2
# Projected Row:1702 Result:1710 2
# Projected Row:1702 Result:1711 2
#   6.28   2.03   0.00  61.44%
# Projected Row:1703 Result:1703 2
# Projected Row:1703 Result:1704 2
# Projected Row:1703 Result:1705 2
# Projected Row:1703 Result:1706 2
# Projected Row:1703 Result:1707 2
# Projected Row:1703 Result:1708 2
# Projected Row:1703 Result:1709 2
# Projected Row:1703 Result:1710 2
# Projected Row:1703 Result:1711 2
# Projected Row:1703 Result:1712 2
#   5.52   2.03   0.00  61.60%
# Projected Row:1704 Result:1704 2
# Projected Row:1704 Result:1705 2
# Projected Row:1704 Result:1706 0
# Projected Row:1704 Result:1707 2
# Projected Row:1704 Result:1708 2
# Projected Row:1704 Result:1709 2
# Projected Row:1704 Result:1710 2
# Projected Row:1704 Result:1711 2
# Projected Row:1704 Result:1712 2
# Projected Row:1704 Result:1713 2
#   3.47   3.29   0.00  61.48%
# Projected Row:1705 Result:1705 2
# Projected Row:1705 Result:1706 2
# Projected Row:1705 Result:1707 2
# Projected Row:1705 Result:1708 2
# Projected Row:1705 Result:1709 2
# Projected Row:1705 Result:1710 2
# Projected Row:1705 Result:1711 2
# Projected Row:1705 Result:1712 2
# Projected Row:1705 Result:1713 2
# Projected Row:1705 Result:1714 2
#   4.97   1.90   0.00  61.60%
# Projected Row:1706 Result:1706 2
# Projected Row:1706 Result:1707 2
# Projected Row:1706 Result:1708 2
# Projected Row:1706 Result:1709 2
# Projected Row:1706 Result:1710 0
# Projected Row:1706 Result:1711 2
# Projected Row:1706 Result:1712 2
# Projected Row:1706 Result:1713 2
# Projected Row:1706 Result:1714 2
# Projected Row:1706 Result:1715 2
#   4.18   5.06   0.00  61.35%
# Projected Row:1707 Result:1707 2
# Projected Row:1707 Result:1708 2
# Projected Row:1707 Result:1709 2
# Projected Row:1707 Result:1710 2
# Projected Row:1707 Result:1711 2
# Projected Row:1707 Result:1712 2
# Projected Row:1707 Result:1713 2
# Projected Row:1707 Result:1714 2
# Projected Row:1707 Result:1715 2
# Projected Row:1707 Result:1716 2
#   4.52   4.55   0.00  61.18%
# Projected Row:1708 Result:1708 2
# Projected Row:1708 Result:1709 2
# Projected Row:1708 Result:1710 2
# Projected Row:1708 Result:1711 2
# Projected Row:1708 Result:1712 2
# Projected Row:1708 Result:1713 2
# Projected Row:1708 Result:1714 2
# Projected Row:1708 Result:1715 2
# Projected Row:1708 Result:1716 2
# Projected Row:1708 Result:1717 2
#   6.88   4.55   0.00  61.16%
# Projected Row:1709 Result:1709 2
# Projected Row:1709 Result:1710 2
# Projected Row:1709 Result:1711 2
# Projected Row:1709 Result:1712 2
# Projected Row:1709 Result:1713 2
# Projected Row:1709 Result:1714 2
# Projected Row:1709 Result:1715 2
# Projected Row:1709 Result:1716 2
# Projected Row:1709 Result:1717 2
# Projected Row:1709 Result:1718 2
#   7.17   3.16   0.00  61.30%
# Projected Row:1710 Result:1710 2
# Projected Row:1710 Result:1711 2
# Projected Row:1710 Result:1712 2
# Projected Row:1710 Result:1713 2
# Projected Row:1710 Result:1714 2
# Projected Row:1710 Result:1715 2
# Projected Row:1710 Result:1716 2
# Projected Row:1710 Result:1717 2
# Projected Row:1710 Result:1718 2
# Projected Row:1710 Result:1719 2
#   7.17   4.83   0.00  61.27%
# Projected Row:1711 Result:1711 2
# Projected Row:1711 Result:1712 2
# Projected Row:1711 Result:1713 2
# Projected Row:1711 Result:1714 0
# Projected Row:1711 Result:1715 2
# Projected Row:1711 Result:1716 2
# Projected Row:1711 Result:1717 2
# Projected Row:1711 Result:1718 2
# Projected Row:1711 Result:1719 2
# Projected Row:1711 Result:1720 0
#   6.15   6.81   0.00  60.99%
# Projected Row:1712 Result:1712 0
# Projected Row:1712 Result:1713 2
# Projected Row:1712 Result:1714 2
# Projected Row:1712 Result:1715 2
# Projected Row:1712 Result:1716 2
# Projected Row:1712 Result:1717 2
# Projected Row:1712 Result:1718 2
# Projected Row:1712 Result:1719 2
# Projected Row:1712 Result:1720 0
# Projected Row:1712 Result:1721 2
#   5.42   7.35   0.00  60.64%
# Projected Row:1713 Result:1713 2
# Projected Row:1713 Result:1714 2
# Projected Row:1713 Result:1715 2
# Projected Row:1713 Result:1716 2
# Projected Row:1713 Result:1717 2
# Projected Row:1713 Result:1718 2
# Projected Row:1713 Result:1719 2
# Projected Row:1713 Result:1720 2
# Projected Row:1713 Result:1721 2
# Projected Row:1713 Result:1722 2
#   6.89   4.88   0.00  60.60%
# Projected Row:1714 Result:1714 0
# Projected Row:1714 Result:1715 0
# Projected Row:1714 Result:1716 2
# Projected Row:1714 Result:1717 2
# Projected Row:1714 Result:1718 2
# Projected Row:1714 Result:1719 2
# Projected Row:1714 Result:1720 0
# Projected Row:1714 Result:1721 2
# Projected Row:1714 Result:1722 2
# Projected Row:1714 Result:1723 2
#   7.56   4.27   0.00  60.66%
# Projected Row:1715 Result:1715 2
# Projected Row:1715 Result:1716 2
# Projected Row:1715 Result:1717 2
# Projected Row:1715 Result:1718 2
# Projected Row:1715 Result:1719 2
# Projected Row:1715 Result:1720 2
# Projected Row:1715 Result:1721 2
# Projected Row:1715 Result:1722 2
# Projected Row:1715 Result:1723 2
# Projected Row:1715 Result:1724 2
#   6.54   4.94   0.00  60.60%
# Projected Row:1716 Result:1716 2
# Projected Row:1716 Result:1717 2
# Projected Row:1716 Result:1718 2
# Projected Row:1716 Result:1719 2
# Projected Row:1716 Result:1720 2
# Projected Row:1716 Result:1721 2
# Projected Row:1716 Result:1722 2
# Projected Row:1716 Result:1723 2
# Projected Row:1716 Result:1724 2
# Projected Row:1716 Result:1725 2
#   6.54   2.33   0.00  60.76%
# Projected Row:1717 Result:1717 2
# Projected Row:1717 Result:1718 2
# Projected Row:1717 Result:1719 2
# Projected Row:1717 Result:1720 2
# Projected Row:1717 Result:1721 2
# Projected Row:1717 Result:1722 2
# Projected Row:1717 Result:1723 2
# Projected Row:1717 Result:1724 2
# Projected Row:1717 Result:1725 2
# Projected Row:1717 Result:1726 2
#   8.81   2.33   0.00  61.04%
# Projected Row:1718 Result:1718 2
# Projected Row:1718 Result:1719 2
# Projected Row:1718 Result:1720 2
# Projected Row:1718 Result:1721 2
# Projected Row:1718 Result:1722 2
# Projected Row:1718 Result:1723 2
# Projected Row:1718 Result:1724 2
# Projected Row:1718 Result:1725 2
# Projected Row:1718 Result:1726 2
# Projected Row:1718 Result:1727 2
#   6.02   2.33   0.00  61.17%
# Projected Row:1719 Result:1719 2
# Projected Row:1719 Result:1720 0
# Projected Row:1719 Result:1721 2
# Projected Row:1719 Result:1722 2
# Projected Row:1719 Result:1723 2
# Projected Row:1719 Result:1724 2
# Projected Row:1719 Result:1725 0
# Projected Row:1719 Result:1726 0
# Projected Row:1719 Result:1727 0
# Projected Row:1719 Result:1728 2
#   2.00   6.87   0.00  60.71%
# Projected Row:1720 Result:1720 2
# Projected Row:1720 Result:1721 2
# Projected Row:1720 Result:1722 2
# Projected Row:1720 Result:1723 2
# Projected Row:1720 Result:1724 2
# Projected Row:1720 Result:1725 2
# Projected Row:1720 Result:1726 2
# Projected Row:1720 Result:1727 2
# Projected Row:1720 Result:1728 2
# Projected Row:1720 Result:1729 2
#   6.53   0.87   0.00  60.98%
# Projected Row:1721 Result:1721 2
# Projected Row:1721 Result:1722 2
# Projected Row:1721 Result:1723 2
# Projected Row:1721 Result:1724 2
# Projected Row:1721 Result:1725 2
# Projected Row:1721 Result:1726 0
# Projected Row:1721 Result:1727 2
# Projected Row:1721 Result:1728 2
# Projected Row:1721 Result:1729 2
# Projected Row:1721 Result:1730 2
#   2.11   3.95   0.00  60.77%
# Projected Row:1722 Result:1722 2
# Projected Row:1722 Result:1723 2
# Projected Row:1722 Result:1724 2
# Projected Row:1722 Result:1725 0
# Projected Row:1722 Result:1726 2
# Projected Row:1722 Result:1727 2
# Projected Row:1722 Result:1728 2
# Projected Row:1722 Result:1729 2
# Projected Row:1722 Result:1730 2
# Projected Row:1722 Result:1731 2
#   4.24   0.85   0.00  60.92%
# Projected Row:1723 Result:1723 2
# Projected Row:1723 Result:1724 2
# Projected Row:1723 Result:1725 0
# Projected Row:1723 Result:1726 2
# Projected Row:1723 Result:1727 2
# Projected Row:1723 Result:1728 2
# Projected Row:1723 Result:1729 2
# Projected Row:1723 Result:1730 2
# Projected Row:1723 Result:1731 2
# Projected Row:1723 Result:1732 2
#   4.83   0.79   0.00  61.10%
# Projected Row:1724 Result:1724 2
# Projected Row:1724 Result:1725 0
# Projected Row:1724 Result:1726 2
# Projected Row:1724 Result:1727 2
# Projected Row:1724 Result:1728 2
# Projected Row:1724 Result:1729 2
# Projected Row:1724 Result:1730 2
# Projected Row:1724 Result:1731 0
# Projected Row:1724 Result:1732 2
# Projected Row:1724 Result:1733 2
#   4.98   0.44   0.00  61.32%
# Projected Row:1725 Result:1725 0
# Projected Row:1725 Result:1726 2
# Projected Row:1725 Result:1727 2
# Projected Row:1725 Result:1728 2
# Projected Row:1725 Result:1729 2
# Projected Row:1725 Result:1730 2
# Projected Row:1725 Result:1731 0
# Projected Row:1725 Result:1732 2
# Projected Row:1725 Result:1733 2
# Projected Row:1725 Result:1734 2
#   4.95   0.44   0.00  61.53%
# Projected Row:1726 Result:1726 2
# Projected Row:1726 Result:1727 0
# Projected Row:1726 Result:1728 2
# Projected Row:1726 Result:1729 2
# Projected Row:1726 Result:1730 2
# Projected Row:1726 Result:1731 0
# Projected Row:1726 Result:1732 2
# Projected Row:1726 Result:1733 0
# Projected Row:1726 Result:1734 2
# Projected Row:1726 Result:1735 2
#   6.17   0.60   0.00  61.79%
# Projected Row:1727 Result:1727 2
# Projected Row:1727 Result:1728 2
# Projected Row:1727 Result:1729 2
# Projected Row:1727 Result:1730 2
# Projected Row:1727 Result:1731 2
# Projected Row:1727 Result:1732 2
# Projected Row:1727 Result:1733 2
# Projected Row:1727 Result:1734 2
# Projected Row:1727 Result:1735 2
# Projected Row:1727 Result:1736 2
#   3.28   0.46   0.00  61.91%
